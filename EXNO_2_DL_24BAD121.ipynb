# %% [markdown]
# <a href="https://colab.research.google.com/github/Swasthika3/DL-24BAD121-/blob/main/EXNO_2_DL_24BAD121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK A — VISUALIZATION OF ACTIVATION FUNCTIONS

# %%
# EXPERIMENT NO: 2
# COMPARATIVE STUDY OF ACTIVATION FUNCTIONS AND OPTIMIZATION ALGORITHMS
print("SWASTHIKA M 24BAD121")

import numpy as np
import matplotlib.pyplot as plt

# Input values
x = np.linspace(-10, 10, 400)

# Activation functions
sigmoid = 1 / (1 + np.exp(-x))
tanh = np.tanh(x)
relu = np.maximum(0, x)

# Plot Sigmoid
plt.figure(figsize=(8, 5))
plt.plot(x, sigmoid)
plt.title("Sigmoid Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.show()

# Plot Tanh
plt.figure(figsize=(8, 5))
plt.plot(x, tanh)
plt.title("Tanh Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.show()

# Plot ReLU
plt.figure(figsize=(8, 5))
plt.plot(x, relu)
plt.title("ReLU Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.show()

# Combined plot
plt.figure(figsize=(10, 6))
plt.plot(x, sigmoid, label="Sigmoid")
plt.plot(x, tanh, label="Tanh")
plt.plot(x, relu, label="ReLU")

plt.title("Comparison of Activation Functions")
plt.xlabel("Input")
plt.ylabel("Output")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# SWASTHIKA M 24BAD121

# %% [markdown]
# TASK B — PERFORMANCE COMPARISON

# %%
print("SWASTHIKA M 24BAD121")
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten
import matplotlib.pyplot as plt

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize pixel values
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Validation data
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train_new = x_train[:-10000]
y_train_new = y_train[:-10000]

# Function to create model
def create_model(activation):

    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation=activation),
        Dense(64, activation=activation),
        Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# Activation functions
activations = ["sigmoid", "tanh", "relu"]

histories = {}

for activation in activations:

    print("\nTraining with:", activation)

    model = create_model(activation)

    history = model.fit(
        x_train_new,
        y_train_new,
        validation_data=(x_val, y_val),
        epochs=10,
        batch_size=128,
        verbose=1
    )

    histories[activation] = history
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Training with: sigmoid
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8087 - loss: 0.8583 - val_accuracy: 0.9145 - val_loss: 0.3382
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9186 - loss: 0.2959 - val_accuracy: 0.9361 - val_loss: 0.2296
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9363 - loss: 0.2220 - val_accuracy: 0.9472 - val_loss: 0.1847
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9473 - loss: 0.1811 - val_accuracy: 0.9544 - val_loss: 0.1639
# Epoch 5/10
# ...

# %% [markdown]
# Plot training and validation accuracy

# %%
plt.figure(figsize=(10, 6))

for activation in activations:
    plt.plot(
        histories[activation].history["accuracy"],
        label=activation + " Training"
    )

    plt.plot(
        histories[activation].history["val_accuracy"],
        linestyle="--",
        label=activation + " Validation"
    )

plt.title("Training and Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Plot loss

# %%
plt.figure(figsize=(10, 6))

for activation in activations:
    plt.plot(
        histories[activation].history["loss"],
        label=activation + " Training"
    )

    plt.plot(
        histories[activation].history["val_loss"],
        linestyle="--",
        label=activation + " Validation"
    )

plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Generate comparison results

# %%
print("ACTIVATION FUNCTION COMPARISON")
print("-" * 70)

for activation in activations:

    history = histories[activation].history

    print("\nActivation:", activation)
    print("Final Training Accuracy:",
          round(history["accuracy"][-1], 4))
    print("Final Validation Accuracy:",
          round(history["val_accuracy"][-1], 4))
    print("Final Training Loss:",
          round(history["loss"][-1], 4))
    print("Final Validation Loss:",
          round(history["val_loss"][-1], 4))
# Out:
# ACTIVATION FUNCTION COMPARISON
# ----------------------------------------------------------------------
#
# Activation: sigmoid
# Final Training Accuracy: 0.9791
# Final Validation Accuracy: 0.9698
# Final Training Loss: 0.0726
# Final Validation Loss: 0.0982
#
# Activation: tanh
# Final Training Accuracy: 0.9943
# Final Validation Accuracy: 0.975
# Final Training Loss: 0.0226
# Final Validation Loss: 0.0835
#
# Activation: relu
# Final Training Accuracy: 0.9928
# Final Validation Accuracy: 0.9781
# Final Training Loss: 0.0223
# Final Validation Loss: 0.0894

# %% [markdown]
# TASK C — OPTIMIZATION ALGORITHMS

# %%
print("SWASTHIKA M 24BAD121")
# EXPERIMENT 02 - TASK C


# -------------------- IMPORT LIBRARIES -----------------------
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
print("TASK C: OPTIMIZATION ALGORITHM COMPARISON")

print("TensorFlow Version:", tf.__version__)

# -------------------- LOAD MNIST DATASET --------------------
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize pixel values
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Flatten images: 28x28 -> 784
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

print("\nTraining Data Shape:", x_train.shape)
print("Testing Data Shape :", x_test.shape)

# -------------------- ANN MODEL -----------------------------
def create_model(optimizer):

    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(784,)),

        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# -------------------- OPTIMIZERS ----------------------------
optimizers = {
    "SGD": tf.keras.optimizers.SGD(
        learning_rate=0.01
    ),

    "Momentum": tf.keras.optimizers.SGD(
        learning_rate=0.01,
        momentum=0.9
    ),

    "RMSProp": tf.keras.optimizers.RMSprop(
        learning_rate=0.001
    ),

    "Adam": tf.keras.optimizers.Adam(
        learning_rate=0.001
    )
}

# -------------------- TRAIN MODELS --------------------------
histories = {}
models = {}

EPOCHS = 15
BATCH_SIZE = 128

for name, optimizer in optimizers.items():

    print("\n" + "=" * 60)
    print("Training using:", name)
    print("=" * 60)

    model = create_model(optimizer)

    history = model.fit(
        x_train,
        y_train,
        validation_split=0.2,
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        verbose=1
    )

    histories[name] = history.history
    models[name] = model

# -------------------- LOSS GRAPH ----------------------------
plt.figure(figsize=(10, 6))

for name, history in histories.items():
    plt.plot(
        history["loss"],
        label=name
    )

plt.title("Training Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.legend()
plt.grid(True)
plt.show()

# -------------------- VALIDATION LOSS GRAPH -----------------
plt.figure(figsize=(10, 6))

for name, history in histories.items():
    plt.plot(
        history["val_loss"],
        label=name
    )

plt.title("Validation Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# -------------------- ACCURACY GRAPH ------------------------
plt.figure(figsize=(10, 6))

for name, history in histories.items():
    plt.plot(
        history["accuracy"],
        label=name
    )

plt.title("Training Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# -------------------- VALIDATION ACCURACY GRAPH -------------
plt.figure(figsize=(10, 6))

for name, history in histories.items():
    plt.plot(
        history["val_accuracy"],
        label=name
    )

plt.title("Validation Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# -------------------- PERFORMANCE TABLE --------------------
results = []

for name, history in histories.items():

    results.append({
        "Optimizer": name,
        "Final Training Loss": history["loss"][-1],
        "Final Validation Loss": history["val_loss"][-1],
        "Final Training Accuracy": history["accuracy"][-1],
        "Final Validation Accuracy": history["val_accuracy"][-1]
    })

results_df = pd.DataFrame(results)

# Sort according to validation accuracy
results_df = results_df.sort_values(
    by="Final Validation Accuracy",
    ascending=False
)

print("\n====================================================")
print("OPTIMIZER PERFORMANCE COMPARISON")
print("====================================================")

display(results_df)

# -------------------- TEST ACCURACY -------------------------
test_results = []

for name, model in models.items():

    test_loss, test_accuracy = model.evaluate(
        x_test,
        y_test,
        verbose=0
    )

    test_results.append({
        "Optimizer": name,
        "Test Loss": test_loss,
        "Test Accuracy": test_accuracy
    })

test_df = pd.DataFrame(test_results)

test_df = test_df.sort_values(
    by="Test Accuracy",
    ascending=False
)

print("\n====================================================")
print("TEST SET PERFORMANCE")
print("====================================================")

display(test_df)

# -------------------- BEST OPTIMIZER ------------------------
best_optimizer = test_df.iloc[0]["Optimizer"]
best_accuracy = test_df.iloc[0]["Test Accuracy"]

print("\n====================================================")
print("FINAL RESULT")
print("====================================================")
print("Best Optimizer       :", best_optimizer)
print("Best Test Accuracy   :", round(best_accuracy * 100, 2), "%")
print("====================================================")

print("\nConclusion:")
print(
    "Adam generally provides fast and stable convergence because "
    "it uses adaptive learning rates and momentum-based updates. "
    "Momentum improves SGD convergence, while RMSProp adapts "
    "the learning rate for each parameter."
)
# Out:
# SWASTHIKA M 24BAD121
# TASK C: OPTIMIZATION ALGORITHM COMPARISON
# TensorFlow Version: 2.20.0
#
# Training Data Shape: (60000, 784)
# Testing Data Shape : (10000, 784)
#
# ...
# Training using: SGD
# ...
# Epoch 1/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6394 - loss: 1.4040 - val_accuracy: 0.8370 - val_loss: 0.6957
# Epoch 2/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8526 - loss: 0.5729 - val_accuracy: 0.8805 - val_loss: 0.4461
# Epoch 3/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8803 - loss: 0.4346 - val_accuracy: 0.8926 - val_loss: 0.3760
# Epoch 4/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8934 - loss: 0.3797 - val_accuracy: 0.9025 - val_loss: 0.3408
# Epoch 5/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9015 - loss: 0.3470 - val_accuracy: 0.9084 - val_loss: 0.3147
# Epoch 6/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9079 - loss: 0.3240 - val_accuracy: 0.9123 - val_loss: 0.2984
# Epoch 7/15
# ...

# %%
# ============================================================
# EXPERIMENT 02 - TASK D
# DEEP LEARNING EXPERIMENT MANAGEMENT
# Google Colab + Google Drive + GitHub
# ============================================================



# ============================================================
# 1. IMPORT LIBRARIES
# ============================================================

import os
import shutil
import pandas as pd
from google.colab import drive

print("====================================================")
print("TASK D: DEEP LEARNING EXPERIMENT MANAGEMENT")
print("====================================================")

print("Roll Numbers:")
print("SWASTHIKA M 24BAD121")

# ============================================================
# 2. MOUNT GOOGLE DRIVE
# ============================================================

print("\nMounting Google Drive...")

drive.mount('/content/drive')

print("Google Drive mounted successfully!")

# ============================================================
# 3. CREATE EXPERIMENT FOLDER
# ============================================================

experiment_path = "/content/drive/MyDrive/DL_Experiment_02"

os.makedirs(experiment_path, exist_ok=True)

print("\nExperiment folder:")
print(experiment_path)

# ============================================================
# 4. CREATE SUBFOLDERS
# ============================================================

models_path = os.path.join(experiment_path, "models")
results_path = os.path.join(experiment_path, "results")

os.makedirs(models_path, exist_ok=True)
os.makedirs(results_path, exist_ok=True)

print("\nFolders created:")
print("Main Folder :", experiment_path)
print("Models      :", models_path)
print("Results     :", results_path)

# ============================================================
# 5. SAVE OPTIMIZER RESULTS
# ============================================================

# This uses results_df created in TASK C.
# If results_df exists, save it.

if "results_df" in globals():

    optimizer_results_file = os.path.join(
        results_path,
        "optimizer_results.csv"
    )

    results_df.to_csv(
        optimizer_results_file,
        index=False
    )

    print("\nOptimizer results saved:")
    print(optimizer_results_file)

else:

    print("\nresults_df not found.")
    print("Run Task C before Task D to save optimizer results.")

# ============================================================
# 6. SAVE TEST RESULTS
# ============================================================

if "test_df" in globals():

    test_results_file = os.path.join(
        results_path,
        "test_results.csv"
    )

    test_df.to_csv(
        test_results_file,
        index=False
    )

    print("\nTest results saved:")
    print(test_results_file)

else:

    print("\ntest_df not found.")
    print("Run Task C before Task D to save test results.")

# ============================================================
# 7. SAVE ALL TRAINED MODELS
# ============================================================

if "models" in globals():

    for name, model in models.items():

        model_file = os.path.join(
            models_path,
            name.lower() + "_model.keras"
        )

        model.save(model_file)

        print("Saved:", name, "model")

    print("\nAll trained models saved successfully!")

else:

    print("\nModels not found.")
    print("Run Task C before Task D.")

# ============================================================
# 8. SAVE BEST MODEL
# ============================================================

if "test_df" in globals() and "models" in globals():

    best_optimizer = test_df.iloc[0]["Optimizer"]

    best_model = models[best_optimizer]

    best_model_path = os.path.join(
        experiment_path,
        "best_model.keras"
    )

    best_model.save(best_model_path)

    print("\nBest Optimizer:", best_optimizer)
    print("Best model saved at:")
    print(best_model_path)

# ============================================================
# 9. CREATE README FILE
# ============================================================

readme_content = f"""
# Deep Learning Experiment 02

## Comparative Study of Activation Functions
## and Optimization Algorithms


## Dataset

MNIST Handwritten Digit Dataset

## Neural Network Architecture

- Input Layer: 784 neurons
- Hidden Layer 1: 128 neurons
- Hidden Layer 2: 64 neurons
- Output Layer: 10 neurons
- Hidden Activation: ReLU
- Output Activation: Softmax

## Optimizers Compared

1. SGD
2. Momentum
3. RMSProp
4. Adam

## Experiment Objective

To compare different optimization algorithms and analyze
their effect on training loss, validation loss,
convergence speed and accuracy.

## Experiment Management

Google Colab was used for executing the deep learning
experiment.

Google Drive was used to store notebooks, trained models
and experiment results.

GitHub was used for version control and maintaining
the history of the experiment.

## Files

- Experiment notebook
- optimizer_results.csv
- test_results.csv
- best_model.keras
- models/
- results/

## Conclusion

Optimization algorithms affect the convergence speed
and performance of neural networks. Adam generally
provides fast and stable convergence.
"""

readme_path = os.path.join(
    experiment_path,
    "README.md"
)

with open(readme_path, "w") as file:
    file.write(readme_content)

print("\nREADME.md created successfully!")
print(readme_path)

# ============================================================
# 10. DISPLAY EXPERIMENT FILES
# ============================================================

print("\n====================================================")
print("EXPERIMENT FILES")
print("====================================================")

for root, dirs, files in os.walk(experiment_path):

    level = root.replace(
        experiment_path, ""
    ).count(os.sep)

    indent = "    " * level

    print(indent + os.path.basename(root) + "/")

    for file in files:
        print(indent + "    " + file)
# Out:
# ...
# TASK D: DEEP LEARNING EXPERIMENT MANAGEMENT
# ...
# Roll Numbers:
# SWASTHIKA M 24BAD121
#
# Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive mounted successfully!
#
# Experiment folder:
# /content/drive/MyDrive/DL_Experiment_02
#
# Folders created:
# Main Folder : /content/drive/MyDrive/DL_Experiment_02
# Models      : /content/drive/MyDrive/DL_Experiment_02/models
# Results     : /content/drive/MyDrive/DL_Experiment_02/results
#
# Optimizer results saved:
# /content/drive/MyDrive/DL_Experiment_02/results/optimizer_results.csv
#
# Test results saved:
# /content/drive/MyDrive/DL_Experiment_02/results/test_results.csv
# Saved: SGD model
# Saved: Momentum model
# Saved: RMSProp model
# Saved: Adam model
#
# All trained models saved successfully!
#
# Best Optimizer: RMSProp
# Best model saved at:
# /content/drive/MyDrive/DL_Experiment_02/best_model.keras
#
# ...
